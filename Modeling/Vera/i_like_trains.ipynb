# %%
import pandas as pd
import numpy as np

# %%
nodes_norway = pd.read_csv("../../Extraction/out/nodes_GTFS_ALL_FYLKER.csv")
edges_norway = pd.read_csv("../../Extraction/out/edges_GTFS_ALL_FYLKER_with_mondayTrips.csv")
display(nodes_norway.head()) 
display(edges_norway.head())
# Out:
#                id     stopPlaceId                name        lat        lon  \
# 0   NSR:Quay:1173   NSR:Quay:1173       Oslo lufthavn  60.194220  11.099609
# 1  NSR:Quay:26169  NSR:Quay:26169  Sundvollen sentrum  60.062000  10.309736
# 2  NSR:Quay:26153  NSR:Quay:26153            Kroksund  60.066087  10.297885
# 3  NSR:Quay:26147  NSR:Quay:26147           Paddevika  60.074500  10.300500
# 4  NSR:Quay:26140  NSR:Quay:26140             Vik E16  60.077880  10.287076
#
#                modes    stopType
# 0            unknown     unknown
# 1                bus         bus
# 2                bus         bus
# 3                bus         bus
# 4  bus,coach service  multimodal
#              from              to               lineId  \
# 0   NSR:Quay:1173   NSR:Quay:1173  AVI:Line:WF_OSL-OSL
# 1  NSR:Quay:26169  NSR:Quay:26153     BRA:Line:26_4260
# 2  NSR:Quay:26153  NSR:Quay:26147     BRA:Line:26_4260
# 3  NSR:Quay:26147  NSR:Quay:26140     BRA:Line:26_4260
# 4  NSR:Quay:26140  NSR:Quay:26116     BRA:Line:26_4260
#
#                          lineCode     mode          authority  travelTimeSec  \
# 0                       Oslo-Oslo  unknown             Avinor        11400.0
# 1  Flybuss Ringerike - Gardermoen      bus  Askeladden Reiser            NaN
# 2  Flybuss Ringerike - Gardermoen      bus  Askeladden Reiser           60.0
# 3  Flybuss Ringerike - Gardermoen      bus  Askeladden Reiser           60.0
# 4  Flybuss Ringerike - Gardermoen      bus  Askeladden Reiser           60.0
#
#    tripsInFeed  tripsOn2025_11_17
# 0            5                  2
# 1            6                  8
# 2            6                  8
# 3            6                  8
# 4            6                  8

# %%
edges_norway = edges_norway[edges_norway["mode"] == "rail"]
nodes_norway = nodes_norway[nodes_norway["modes"].str.contains("rail")]
display(edges_norway.head())
display(nodes_norway.head())
print(f"Edges shape Oslo: {edges_norway.shape} | Nodes/Stops shape: {nodes_norway.shape}")
# Out:
#                from            to         lineId lineCode  mode authority  \
# 9085  NSR:Quay:1150  NSR:Quay:247  FLT:Line:FLY2     FLY2  rail  Flytoget
# 9086   NSR:Quay:247  NSR:Quay:236  FLT:Line:FLY2     FLY2  rail  Flytoget
# 9087   NSR:Quay:236  NSR:Quay:476  FLT:Line:FLY2     FLY2  rail  Flytoget
# 9088   NSR:Quay:476  NSR:Quay:557  FLT:Line:FLY2     FLY2  rail  Flytoget
# 9089   NSR:Quay:557  NSR:Quay:447  FLT:Line:FLY2     FLY2  rail  Flytoget
#
#       travelTimeSec  tripsInFeed  tripsOn2025_11_17
# 9085          240.0         2940                100
# 9086          180.0         2940                100
# 9087          240.0         2940                100
# 9088          360.0         2940                100
# 9089         1140.0         6042                100
#                  id     stopPlaceId               name        lat        lon  \
# 535  NSR:Quay:30086  NSR:Quay:30086     Gulskogen gård  59.746154  10.163695
# 555  NSR:Quay:28541  NSR:Quay:28541  Mjøndalen stasjon  59.750479  10.012134
# 574  NSR:Quay:30087  NSR:Quay:30087     Gulskogen gård  59.745948  10.163864
# 579  NSR:Quay:28539  NSR:Quay:28539  Mjøndalen stasjon  59.750649  10.011621
# 619  NSR:Quay:26294  NSR:Quay:26294   Hokksund stasjon  59.767310   9.911250
#
#         modes    stopType
# 535  bus,rail  multimodal
# 555  bus,rail  multimodal
# 574  bus,rail  multimodal
# 579  bus,rail  multimodal
# 619  bus,rail  multimodal
# Edges shape Oslo: (1156, 9) | Nodes/Stops shape: (349, 7)

# %%
stop_dict = {}

for _, row in nodes_norway.iterrows():
    stop_id = row["stopPlaceId"]
    name = row["name"]
    stop_dict[stop_id] = name

# %%
edges_norway = edges_norway.rename(columns={"from": "from_stop"})
edges_norway = edges_norway.rename(columns={"to": "to_stop"})

for row in edges_norway.itertuples():
    edges_norway.loc[row.Index, "from_stop"] = stop_dict[row.from_stop]
    edges_norway.loc[row.Index, "to_stop"] = stop_dict[row.to_stop]

# %%
display(edges_norway.head())
# Out:
#                      from_stop                   to_stop         lineId  \
# 9085           Stabekk stasjon           Lysaker stasjon  FLT:Line:FLY2
# 9086           Lysaker stasjon            Skøyen stasjon  FLT:Line:FLY2
# 9087            Skøyen stasjon  Nationaltheatret stasjon  FLT:Line:FLY2
# 9088  Nationaltheatret stasjon                    Oslo S  FLT:Line:FLY2
# 9089                    Oslo S     Oslo lufthavn stasjon  FLT:Line:FLY2
#
#      lineCode  mode authority  travelTimeSec  tripsInFeed  tripsOn2025_11_17
# 9085     FLY2  rail  Flytoget          240.0         2940                100
# 9086     FLY2  rail  Flytoget          180.0         2940                100
# 9087     FLY2  rail  Flytoget          240.0         2940                100
# 9088     FLY2  rail  Flytoget          360.0         2940                100
# 9089     FLY2  rail  Flytoget         1140.0         6042                100

# %%
stop_times = pd.read_csv("stop_times.txt")
calender_dates = pd.read_csv("calendar_dates.txt")
display(calender_dates.head())
display(stop_times.head())
# Out:
#                                           service_id      date  exception_type
# 0  VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...  20251119               1
# 1  VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...  20251120               1
# 2  VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...  20251121               1
# 3  VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...  20251122               1
# 4  VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...  20251123               1
#                             trip_id        stop_id arrival_time  \
# 0  VYG:ServiceJourney:1002_385192-R  NSR:Quay:1038     04:42:00
# 1  VYG:ServiceJourney:1002_385192-R   NSR:Quay:195     04:55:00
# 2  VYG:ServiceJourney:1002_385192-R   NSR:Quay:886     05:07:00
# 3  VYG:ServiceJourney:1002_385192-R    NSR:Quay:83     05:14:00
# 4  VYG:ServiceJourney:1002_385192-R   NSR:Quay:736     05:17:00
#
#   departure_time  stop_sequence  pickup_type  drop_off_type  \
# 0       04:42:00              1          NaN            1.0
# 1       04:55:00              2          NaN            NaN
# 2       05:08:00              3          NaN            NaN
# 3       05:14:00              4          NaN            NaN
# 4       05:17:00              5          NaN            NaN
#
#    shape_dist_traveled
# 0                  0.0
# 1              21063.0
# 2              41884.0
# 3              51426.0
# 4              53495.0

# %%
calender_dates = calender_dates[calender_dates["date"] == 20251124]
monday_service = calender_dates["service_id"].tolist()
print(monday_service)
# Out:
# ['VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-22-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-29-2025-11-30-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-06-2025-12-07-2025-12-08-2025-12-0-849732677', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-22-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-29-2025-11-30-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-06-2025-12-07-2025-12-08-2025-12-01520547124', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-22-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-29-2025-11-30-2025-12-01-2025-12-07-2025-12-08', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-22-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-29-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-06-2025-12-07-2025-12-08-2025-12-09-2025-12-1-204006637', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-22-2025-11-23-2025-11-24-2025-11-26-2025-11-27-2025-11-28-2025-11-29-2025-11-30-2025-12-01-2025-12-03-2025-12-04-2025-12-05-2025-12-06-2025-12-07-2025-12-08-2025-12-10-2025-12-11-2025-12-1-111911577', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-22-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-29-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-06-2025-12-08-2025-12-09-2025-12-10-2025-12-11-2025-12-1-111911577', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-30-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-07-2025-12-08-2025-12-09-2025-12-10-2025-12-11-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-11-30-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-08-2025-12-09-2025-12-10-2025-12-11-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-28-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-08-2025-12-09-2025-12-10-2025-12-11-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-08-2025-12-09-2025-12-10-2025-12-11-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-24-2025-11-25-2025-11-26-2025-11-28-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-05-2025-12-08-2025-12-09-2025-12-10-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-21-2025-11-24-2025-11-26-2025-11-27-2025-11-28-2025-12-01-2025-12-03-2025-12-04-2025-12-05-2025-12-08-2025-12-10-2025-12-11-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-22-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-29-2025-11-30-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-06-2025-12-07-2025-12-08-2025-12-09-2025-12-10-2025-12-11-2025-12-13', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-23-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-11-30-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-07-2025-12-08-2025-12-09-2025-12-10-2025-12-11', 'VYG:OperatingDay:2025-11-19-2025-11-20-2025-11-24-2025-11-25-2025-11-26-2025-11-27-2025-12-01-2025-12-02-2025-12-03-2025-12-04-2025-12-08-2025-12-09-2025-12-10-2025-12-11', 'VYG:OperatingDay:2025-11-19-2025-11-21-2025-11-24-2025-11-25-2025-11-26-2025-11-28-2025-12-01-2025-12-02-2025-12-03-2025-12-05-2025-12-08-2025-12-09-2025-12-10-2025-12-12', 'VYG:OperatingDay:2025-11-19-2025-11-24-2025-11-25-2025-11-26-2025-12-01-2025-12-02-2025-12-03-2025-12-08-2025-12-09-2025-12-10', 'VYG:OperatingDay:2025-11-20-2025-11-21-2025-11-22-2025-11-23-2025-11-24-2025-11-25-2025-11-27-2025-11-28-2025-11-29-2025-11-30-2025-12-01-2025-12-02-2025-12-04-2025-12-05-2025-12-06-2025-12-07-2025-12-08-2025-12-09-2025-12-11-2025-12-12-2025-12-13', 'VYG:OperatingDay:2025-11-20-2025-11-21-2 ...

# %%
trips = pd.read_csv("trips.txt")
trips = trips[trips["service_id"].isin(monday_service)]
display(trips.head())
monday_trips = trips["trip_id"].tolist()
# Out:
#         route_id                           trip_id  \
# 0   VYG:Line:R14  VYG:ServiceJourney:1002_385192-R
# 2   VYG:Line:R14  VYG:ServiceJourney:1003_348472-R
# 5   VYG:Line:R14  VYG:ServiceJourney:1004_420909-R
# 8   VYG:Line:R14  VYG:ServiceJourney:1005_348474-R
# 12  VYG:Line:R14  VYG:ServiceJourney:1006_420912-R
#
#                                            service_id trip_headsign  \
# 0   VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...         Asker
# 2   VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...   Kongsvinger
# 5   VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...         Asker
# 8   VYG:OperatingDay:2025-11-19-2025-11-20-2025-11...   Kongsvinger
# 12  VYG:OperatingDay:2025-11-23-2025-11-24-2025-11...         Asker
#
#     direction_id                    shape_id  boarding_type
# 0              0  VYG:JourneyPattern:R14-805              0
# 2              0  VYG:JourneyPattern:R14-807              0
# 5              0  VYG:JourneyPattern:R14-805              0
# 8              0  VYG:JourneyPattern:R14-813              0
# 12             0  VYG:JourneyPattern:R14-805              0

# %%
stop_times = stop_times[stop_times["trip_id"].isin(monday_trips)]
stop_times_by_stop = stop_times.sort_values(by=['stop_id', 'departure_time'])
display(stop_times_by_stop.head())
# Out:
#                                     trip_id       stop_id arrival_time  \
# 47874   VYG:ServiceJourney:308-DOM_349009-R   NSR:Quay:10     05:54:00
# 50552   VYG:ServiceJourney:329-SUD_462347-R   NSR:Quay:10     22:04:00
# 19851      VYG:ServiceJourney:1952_252362-R  NSR:Quay:100     06:17:00
# 19894      VYG:ServiceJourney:1954_252364-R  NSR:Quay:100     07:20:00
# 19836  VYG:ServiceJourney:1951-LOD_353990-R  NSR:Quay:100     16:29:00
#
#       departure_time  stop_sequence  pickup_type  drop_off_type  \
# 47874       05:54:00              3          NaN            NaN
# 50552       22:05:00             21          NaN            NaN
# 19851       06:17:00              3          3.0            3.0
# 19894       07:20:00              3          3.0            3.0
# 19836       16:29:00             11          3.0            3.0
#
#        shape_dist_traveled
# 47874              45775.0
# 50552             335498.0
# 19851               9998.0
# 19894               9998.0
# 19836              66957.0

# %%
stop_times_by_stop['departure_time_dt'] = pd.to_timedelta(stop_times_by_stop['departure_time'])
min_gaps = {}
for stop, group in stop_times_by_stop.groupby('stop_id'):
    # Sort departures
    departures = group['departure_time_dt'].sort_values()
    
    # Compute differences between consecutive departures
    diffs = departures.diff().dropna()  # drop the NaT for the first row
    
    if not diffs.empty:
        min_gap = diffs.min()
        min_gaps[stop] = min_gap
    else:
        # Only one departure at this stop
        min_gaps[stop] = pd.Timedelta(0)

print(min_gaps)
# Out:
# {'NSR:Quay:10': Timedelta('0 days 16:11:00'), 'NSR:Quay:100': Timedelta('0 days 00:36:00'), 'NSR:Quay:100138': Timedelta('0 days 00:19:00'), 'NSR:Quay:1002': Timedelta('0 days 00:10:00'), 'NSR:Quay:100304': Timedelta('0 days 00:30:00'), 'NSR:Quay:100305': Timedelta('0 days 00:55:00'), 'NSR:Quay:100308': Timedelta('0 days 00:28:00'), 'NSR:Quay:1008': Timedelta('0 days 00:11:00'), 'NSR:Quay:101598': Timedelta('0 days 00:03:00'), 'NSR:Quay:1017': Timedelta('0 days 00:13:00'), 'NSR:Quay:102': Timedelta('0 days 00:09:00'), 'NSR:Quay:102055': Timedelta('0 days 00:15:00'), 'NSR:Quay:102437': Timedelta('0 days 01:30:00'), 'NSR:Quay:1025': Timedelta('0 days 00:10:00'), 'NSR:Quay:1027': Timedelta('0 days 15:42:00'), 'NSR:Quay:1028': Timedelta('0 days 00:59:00'), 'NSR:Quay:1037': Timedelta('0 days 01:00:00'), 'NSR:Quay:1038': Timedelta('0 days 00:10:00'), 'NSR:Quay:1043': Timedelta('0 days 00:14:00'), 'NSR:Quay:104381': Timedelta('0 days 00:12:00'), 'NSR:Quay:1044': Timedelta('0 days 00:22:00'), 'NSR:Quay:1045': Timedelta('0 days 00:28:00'), 'NSR:Quay:104582': Timedelta('0 days 00:10:00'), 'NSR:Quay:1047': Timedelta('0 days 00:29:00'), 'NSR:Quay:105': Timedelta('0 days 01:00:00'), 'NSR:Quay:1054': Timedelta('0 days 17:12:00'), 'NSR:Quay:1055': Timedelta('0 days 00:18:00'), 'NSR:Quay:1057': Timedelta('0 days 00:27:00'), 'NSR:Quay:105763': Timedelta('0 days 01:00:00'), 'NSR:Quay:1061': Timedelta('0 days 00:14:00'), 'NSR:Quay:106166': Timedelta('0 days 01:00:00'), 'NSR:Quay:1063': Timedelta('0 days 00:14:00'), 'NSR:Quay:1067': Timedelta('0 days 16:54:00'), 'NSR:Quay:1069': Timedelta('0 days 00:09:00'), 'NSR:Quay:1071': Timedelta('0 days 00:32:00'), 'NSR:Quay:107150': Timedelta('0 days 00:03:00'), 'NSR:Quay:107151': Timedelta('0 days 00:04:00'), 'NSR:Quay:1072': Timedelta('0 days 00:10:00'), 'NSR:Quay:107764': Timedelta('0 days 00:16:00'), 'NSR:Quay:108': Timedelta('0 days 00:27:00'), 'NSR:Quay:109': Timedelta('0 days 00:25:00'), 'NSR:Quay:109126': Timedelta('0 days 00:00:00'), 'NSR:Quay:1093': Timedelta('0 days 00:28:00'), 'NSR:Quay:1094': Timedelta('0 days 00:19:00'), 'NSR:Quay:1099': Timedelta('0 days 00:08:00'), 'NSR:Quay:1100': Timedelta('0 days 00:29:00'), 'NSR:Quay:1101': Timedelta('0 days 00:28:00'), 'NSR:Quay:1106': Timedelta('0 days 00:09:00'), 'NSR:Quay:111': Timedelta('0 days 01:18:00'), 'NSR:Quay:1112': Timedelta('0 days 00:16:00'), 'NSR:Quay:1113': Timedelta('0 days 00:28:00'), 'NSR:Quay:1116': Timedelta('0 days 00:15:00'), 'NSR:Quay:1117': Timedelta('0 days 00:14:00'), 'NSR:Quay:1118': Timedelta('0 days 02:00:00'), 'NSR:Quay:1121': Timedelta('0 days 00:30:00'), 'NSR:Quay:1122': Timedelta('0 days 00:29:30'), 'NSR:Quay:1129': Timedelta('0 days 00:26:00'), 'NSR:Quay:113': Timedelta('0 days 00:29:00'), 'NSR:Quay:1130': Timedelta('0 days 00:15:00'), 'NSR:Quay:1134': Timedelta('0 days 00:00:00'), 'NSR:Quay:1136': Timedelta('0 days 00:13:00'), 'NSR:Quay:1137': Timedelta('0 days 01:00:00'), 'NSR:Quay:1140': Timedelta('0 days 00:07:00'), 'NSR:Quay:1150': Timedelta('0 days 00:04:00'), 'NSR:Quay:1151': Timedelta('0 days 00:05:00'), 'NSR:Quay:1154': Timedelta('0 days 00:09:00'), 'NSR:Quay:1157': Timedelta('0 days 00:13:00'), 'NSR:Quay:1158': Timedelta('0 days 00:35:00'), 'NSR:Quay:1168': Timedelta('0 days 00:15:00'), 'NSR:Quay:1170': Timedelta('0 days 00:15:00'), 'NSR:Quay:121': Timedelta('0 days 00:10:00'), 'NSR:Quay:129': Timedelta('0 days 00:06:00'), 'NSR:Quay:13': Timedelta('0 days 00:15:00'), 'NSR:Quay:130': Timedelta('0 days 01:58:00'), 'NSR:Quay:14': Timedelta('0 days 00:14:00'), 'NSR:Quay:141': Timedelta('0 days 00:00:00'), 'NSR:Quay:142': Timedelta('0 days 00:06:00'), 'NSR:Quay:144': Timedelta('0 days 00:24:00'), 'NSR:Quay:149': Timedelta('0 days 00:02:00'), 'NSR:Quay:152': Timedelta('0 days 00:10:00'), 'NSR:Quay:153': Timedelta('0 days 01:11:00'), 'NSR:Quay:157': Timedelta('0 days 00:15:00'), 'NSR:Quay:158': Timedelta('0 days 00:15:00'), 'NSR:Quay:163': Timedelta('0 days 00:12:00'), 'NSR:Quay:169': Timedelta('0 days 00:02:00'),  ...

# %%
nodes_norway['min_headway'] = np.nan

for row in nodes_norway.itertuples():
    if row.stopPlaceId in min_gaps:
        nodes_norway.loc[row.Index, "min_headway"] = min_gaps[row.stopPlaceId]

nodes_norway = nodes_norway.dropna(subset=['min_headway'])

display(nodes_norway.head())
# Out:
# C:\Users\Vegar\AppData\Local\Temp\ipykernel_22700\1322773357.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 days 00:04:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   nodes_norway.loc[row.Index, "min_headway"] = min_gaps[row.stopPlaceId]
#                  id    stopPlaceId                      name        lat  \
# 4383  NSR:Quay:1150  NSR:Quay:1150           Stabekk stasjon  59.907994
# 4384   NSR:Quay:247   NSR:Quay:247           Lysaker stasjon  59.913404
# 4385   NSR:Quay:236   NSR:Quay:236            Skøyen stasjon  59.922268
# 4386   NSR:Quay:476   NSR:Quay:476  Nationaltheatret stasjon  59.915260
# 4387   NSR:Quay:557   NSR:Quay:557                    Oslo S  59.910261
#
#             lon modes stopType      min_headway
# 4383  10.607316  rail     rail  0 days 00:04:00
# 4384  10.637244  rail     rail  0 days 00:04:00
# 4385  10.678630  rail     rail  0 days 00:04:00
# 4386  10.727513  rail     rail  0 days 00:03:00
# 4387  10.754866  rail     rail  0 days 00:00:00
