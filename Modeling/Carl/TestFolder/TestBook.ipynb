# %% [markdown]
# # Data Exploration
# This workbook is used for inspecting and verifying data,
# general testing and debugging, and is therefore not fully focused on rigid documentation.

# %%
import pandas as pd

df = pd.read_csv("verifyingData.csv")

# Show unique route_type values (raw)
print("Unique route_type values:", sorted(df["route_type"].dropna().unique()))

# If you want to see counts too:
print("\nCounts:")
print(df["route_type"].value_counts().sort_index())
# Out:
# Unique route_type values: [np.int64(100), np.int64(101), np.int64(102), np.int64(105), np.int64(106), np.int64(200), np.int64(201), np.int64(202), np.int64(401), np.int64(700), np.int64(701), np.int64(702), np.int64(704), np.int64(705), np.int64(711), np.int64(712), np.int64(714), np.int64(901), np.int64(902), np.int64(1002), np.int64(1004), np.int64(1008), np.int64(1013), np.int64(1014), np.int64(1102), np.int64(1300), np.int64(1500)]
#
# Counts:
# route_type
# 100       40
# 101        2
# 102        4
# 105        3
# 106        3
# 200        1
# 201        5
# 202       33
# 401        5
# 700       29
# 701      241
# 702       29
# 704     1856
# 705       63
# 711        7
# 712     1469
# 714        1
# 901        2
# 902        7
# 1002       2
# 1004     135
# 1008      23
# 1013       7
# 1014      78
# 1102      97
# 1300       1
# 1500       1
# Name: count, dtype: int64
